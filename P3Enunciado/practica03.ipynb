# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from utils import load_data_csv_multi_logistic, zscore_normalize_features


x_train, y_train = load_data_csv_multi_logistic("./data/games-data.csv","score","critics","users","user score")
#x_train, mu, sigma = zscore_normalize_features(x_train)

plt.plot(x_train, y_train)

#plt.show()
# Out:
# [<matplotlib.lines.Line2D at 0x1fc185851f0>,
#  <matplotlib.lines.Line2D at 0x1fc18585220>,
#  <matplotlib.lines.Line2D at 0x1fc18585310>]

# %%
from public_tests_logistic_multi import compute_cost_test, compute_gradient_test

from LogisticRegressionMulti import LogisticRegMulti
from LogisticRegressionMulti import cost_test_multi_obj
from LogisticRegressionMulti import compute_gradient_multi_obj
import pandas as pd
import numpy as np
import math


def test_gradient(x_train, y_train):
    print("------------test_gradient-----------")
    print("---Original---")
    #compute_gradient_test(compute_gradient_matrix)
    print("---POO---")
    compute_gradient_test(compute_gradient_multi_obj)


def test_cost(x_train, y_train):
     print("------------test_cost-----------")
     print("---Original---")
     #compute_cost_test(compute_cost_matrix)
     print("---POO---")
     compute_cost_test(cost_test_multi_obj)


def run_gradient_descent(x_train, y_train,alpha = 0.01,iterations=1500,lambda_=0):
    # initialize fitting parameters. Recall that the shape of w is (n,)
    initial_w = np.zeros(x_train.shape[1])
    initial_b = 0.

    print("---- Gradient descent POO--- lamb ",lambda_)
    lr = LogisticRegMulti(x_train,y_train,initial_w,initial_b,lambda_)
    w,b,h,w_init,b_init = lr.gradient_descent(alpha,iterations)
    
    return w, b



def test_gradient_descent(x_train, y_train):
    #print("----- Original Gradient descent------")
    w1, b1 = run_gradient_descent(x_train, y_train,0.01,1500,0)
    print("w,b found by gradient descent with labmda 0 ([ 0.93305656  0.18903186 -0.12087087] 0.4690649858291144):", w1, b1)

    w2, b2 = run_gradient_descent(x_train, y_train,0.01,1500,1)
    print("w,b found by gradient descent with labmda 1 ([ 0.93278101  0.18900175 -0.12080013] 0.46905464164492655):", w2, b2)


test_cost(x_train, y_train)
test_gradient(x_train, y_train)
test_gradient_descent(x_train, y_train)
# Out:
# ------------test_cost-----------
# ---Original---
# ---POO---
# test1 pasado
# test2 pasado
# test3 pasado
# test4 pasado
# All tests passed!
# ------------test_gradient-----------
# ---Original---
# ---POO---
# All tests passed!
# ---- Gradient descent POO--- lamb  0
# c:\Users\User\Documents\University\ML y MdD\Prácticas\P3Enunciado\LogisticRegressionMulti.py:32: RuntimeWarning: divide by zero encountered in log
#   aux3 = np.log(1 - y_deriv)
# c:\Users\User\Documents\University\ML y MdD\Prácticas\P3Enunciado\LogisticRegressionMulti.py:33: RuntimeWarning: invalid value encountered in multiply
#   total_cost = -np.sum(aux1 + (aux2 * aux3))
# c:\Users\User\Documents\University\ML y MdD\Prácticas\P3Enunciado\LogisticRegressionMulti.py:24: RuntimeWarning: overflow encountered in exp
#   ret = 1 + np.exp(-(aux))
# c:\Users\User\Documents\University\ML y MdD\Prácticas\P3Enunciado\LogisticRegressionMulti.py:30: RuntimeWarning: divide by zero encountered in log
#   aux1 = self.y * np.log(y_deriv)
# c:\Users\User\Documents\University\ML y MdD\Prácticas\P3Enunciado\LogisticRegressionMulti.py:30: RuntimeWarning: invalid value encountered in multiply
#   aux1 = self.y * np.log(y_deriv)
# w,b found by gradient descent with labmda 0 ([ 0.93305656  0.18903186 -0.12087087] 0.4690649858291144): [ 1.56792079e-01  6.44727311e-01 -2.93078530e-07] -0.5137968884671823
# ---- Gradient descent POO--- lamb  1
# w,b found by gradient descent with labmda 1 ([ 0.93278101  0.18900175 -0.12080013] 0.46905464164492655): [ 0.06829683  0.62678431 -0.35701314] -0.5281151865032329
