# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from public_tests import *
from utils import load_data_csv
 
x, y = load_data_csv("data/games-data.csv", "score", "user score")
corr = np.corrcoef(x, y).astype(np.float64)
plt.plot(x, y)
plt.show()

# %%
from practica01 import *

test_gradient(x, y)
test_cost(x, y)
test_gradient_descent(x, y, 0, 0)

test_gradient_v(x, y)
test_cost_v(x, y)
test_gradient_descent_v(x, y, 0, 0)
# Out:
# Gradient at initial w, b (similar to)(-50.498559851122586 -6.988606075159082): -50.49855996441372 -6.9886060907760506
# Gradient at initial w, b (similar to)(-38.7005262336415 -5.369312042261976): -38.70052634693242 -5.369312057878948
# ----Compute gradient POO-------
# Testing: compute_gradient_test
# Using X with shape (4, 1)
# Case 1
# 0.0 0.0
# Case 1 passed!
# Case 2
# Case 2 passed!
# All tests passed!
# <class 'numpy.float64'>
# Cost at initial w (35.841): 35.841
# ----Compute cost POO-------
# Testing: compute_cost_test
# Cost case 1
# Case 1 passed!
# Cost case 2
# Case 2 passed!
# Cost case 3
# Case 3 passed!
# Cost case 4
# Case 4 passed!
# Cost case 5
# Case 5 passed!
# All tests passed!
# for score 3.5, we predict user score of (3.97) 3.97
# 3.9666796635077235
# Case 1
# Case 1 passed!
# for score 7.9, we predict user score of (6.86) 6.86
# Case 2
# 6.858676769680853
# Case 2 passed!
# All tests passed!
# ...
